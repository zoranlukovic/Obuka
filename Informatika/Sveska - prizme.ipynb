# %%
import math

# %%
a = int(input("Unesi stranicu a: "))
H = int(input("Unesi visinu H: "))
# Out:
# Unesi stranicu a:  5
# Unesi visinu H:  8

# %%
B = a**2
M = 4 * (a ** 2)
P = 2 * B + M

# %%
print("Površina prizme je:", P)
# Out:
# Površina prizme je: 150
